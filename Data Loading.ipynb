# %%
spark.sql("SHOW TABLES IN default").show()
# Out:
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# | default|instacart|      false|
# +--------+---------+-----------+

# %%
spark.table("default.instacart").printSchema()
# Out:
# root
#  |-- product_id: long (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- aisle_id: long (nullable = true)
#  |-- department_id: long (nullable = true)
#  |-- order_id: long (nullable = true)
#  |-- user_id: long (nullable = true)
#  |-- eval_set: string (nullable = true)
#  |-- order_number: long (nullable = true)
#  |-- order_dow: long (nullable = true)
#  |-- order_hour_of_day: long (nullable = true)
#  |-- days_since_prior_order: double (nullable = true)
#  |-- add_to_cart_order: long (nullable = true)
#  |-- reordered: long (nullable = true)

# %%
spark.table("default.instacart").show(5)
# Out:
# +----------+------------+--------+-------------+--------+-------+--------+------------+---------+-----------------+----------------------+-----------------+---------+
# |product_id|product_name|aisle_id|department_id|order_id|user_id|eval_set|order_number|order_dow|order_hour_of_day|days_since_prior_order|add_to_cart_order|reordered|
# +----------+------------+--------+-------------+--------+-------+--------+------------+---------+-----------------+----------------------+-----------------+---------+
# |      5684|        NULL|    NULL|         NULL| 1063995|   NULL|    NULL|        NULL|     NULL|             NULL|                  NULL|                6|        1|
# |     13176|        NULL|    NULL|         NULL| 1063995|   NULL|    NULL|        NULL|     NULL|             NULL|                  NULL|                7|        1|
# ...

# %%
instacart_df = spark.table("default.instacart")

filtered_df = instacart_df.filter(
    instacart_df.user_id.isNotNull() &
    instacart_df.product_id.isNotNull()
)

# %%
from pyspark.sql.functions import count

interaction_df = filtered_df.groupBy(
    "user_id", "product_id"
).agg(
    count("*").alias("interaction")
)
